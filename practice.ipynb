# %% [markdown]
# <a href="https://colab.research.google.com/github/rumanakuraishiya/Rumana/blob/main/practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
total

# %%
Expences = [100,250,300,100]

Total = sum(Expences)

print( "Expences:",Expences)
print("Total Expences:",Total)
# Out:
# Expences: [100, 250, 300, 100]
# Total Expences: 750

# %% [markdown]
# Average

# %%
Mark1 = int(input("enter mark 1: "))
Mark2 = int(input("enter mark 2: "))
Mark3 = int(input("enter mark 3: "))

Total =Mark1 +Mark2 +Mark3
Average =Total/3

print("total:",Total)
print("Average:",Average)

if Average>=50:
  print("pass")
else:
  print("fail")
# Out:
# enter mark 1: 30
# enter mark 2: 50
# enter mark 3: 80
# total: 160
# Average: 53.333333333333336
# pass

# %%
def greet():
  print("Welcome")
greet()
# Out:
# Welcome

# %% [markdown]
# NEW SECTION

# %%
def greet(name):
  print("Welcome",name)
greet("Rumana")
# Out:
# Welcome Rumana

# %%
def add(a,b):
  return a+b
result=add(20,30)
print (result)
# Out:
# 50

# %%
def calculate_average(x,y,z):
  return (x + y + z) / 3
try:
  x = int(input("Enter first number:"))
  y = int(input("Enter second number"))
  z = int(input("Enter third number"))
  print("calculate_average =",calculate_average(x,y,z))
except ValueError:
  print("invalid input")
# Out:
# Enter first number:50
# Enter second number60
# Enter third number70
# calculate_average = 60.0
